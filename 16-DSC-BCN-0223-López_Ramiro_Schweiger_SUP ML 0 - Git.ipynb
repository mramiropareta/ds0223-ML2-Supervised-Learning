# %% [markdown]
# ### ALUMNAS: Laura López, Marina Ramiro, Sofía Schweiger

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# current directory
# %cd '/content/drive/MyDrive/NDS_2023'
# Out:
# /content/drive/MyDrive/NDS_2023

# %%
# %pwd #print working directory
# Out:
# '/content/drive/MyDrive/NDS_2023'

# %%
# !git clone https://github.com/isolway/EJERCICIO-ML-Sup.git
# Out:
# Cloning into 'EJERCICIO-ML-Sup'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 11 (delta 2), reused 11 (delta 2), pack-reused 0
# Unpacking objects: 100% (11/11), 14.17 MiB | 6.98 MiB/s, done.
